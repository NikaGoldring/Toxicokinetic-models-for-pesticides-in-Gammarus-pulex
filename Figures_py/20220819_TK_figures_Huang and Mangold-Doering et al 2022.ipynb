# %% [markdown]
# # Introduction
#
# This Jupyter Notebook contains the code used to produce the figures within the research article published by Huang and Mangold-Döring et al. 2022 (https://doi.org/).
#
#
# ## What is plotted here?
# For the model code that generated the predictions plotted below, see the MatLab code in the GitHub repository. The measured raw data can be found in the associated Mendeley Data (link).
#
# ## Why though?
# For additional information on the research, please refer to the original article and its supporting information: Huang and Mangold-Döring et al. (submitted to STOTEN in July 2022).
#
# ### You think this code is ugly?
# Well, that makes two of us. If you have time to clean it up, please consider to share your tidy version with the rest of us <3!

# %% [markdown]
# ## 1. Initial settings
# #### Load packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Define plot specifications

# %%
import matplotlib as mpl
mpl.rcParams['axes.spines.right'] = False  #no line on the right side of the plot
mpl.rcParams['axes.spines.top'] = False    #no line on the top of the plot
mpl.rcParams['font.size'] = '15'           #define font size to 15

# %% [markdown]
# ## 2. Prepare data to be plotted
#
# #### Read data from txt files

# %%
#IMI-models ###############################################################################################################
filename = '20220125_IMI_standard_07.txt' #parent
data_array = np.loadtxt(filename, delimiter=',', dtype=float)
#print(data_array)

filename1 = '20220506_IMI_parent_18.txt' #parent
data_array1 = np.loadtxt(filename1, delimiter=',', dtype=float)
#print(data_array1)

filename2 = '20220506_IMI_parent_24.txt' #parent 
data_array2 = np.loadtxt(filename2, delimiter=',', dtype=float)
#print(data_array2)

#FPF-models ###############################################################################################################
filename3 = '20220125_FPF_standard_07.txt' 
data_array3 = np.loadtxt(filename3, delimiter=',', dtype=float)
#print(data_array3)

filename4 = '20220125_FPF_standard_18.txt' 
data_array4 = np.loadtxt(filename4, delimiter=',', dtype=float)
#print(data_array4)

filename5 = '20220125_FPF_standard_24.txt' 
data_array5 = np.loadtxt(filename5, delimiter=',', dtype=float)
#print(data_array5)

# %%
#IMI-models ###############################################################################################################
filename6 = '20220506_IMI_metabolite_18.txt' #metabolite
data_array6 = np.loadtxt(filename6, delimiter=',', dtype=float)
#print(data_array6)

filename7 = '20220506_IMI_metabolite_24.txt' #metabolite
data_array7 = np.loadtxt(filename7, delimiter=',', dtype=float)
#print(data_array7)

# %% [markdown]
# #### Convert imported array into df

# %%
#IMI-models ###############################################################################################################
df = pd.DataFrame(data=data_array, 
                  columns=["time","upCI","lowCI","model"])
#print(df)

df1 = pd.DataFrame(data=data_array1, 
                  columns=["time","upCI","lowCI","model"])
#print(df1)

df2 = pd.DataFrame(data=data_array2, 
                  columns=["time","upCI","lowCI","model"])
#print(df2)

#IMI-ole models ###########################################################################################################
df6 = pd.DataFrame(data=data_array6, 
                  columns=["time","upCI","lowCI","model"])
#print(df6)

df7 = pd.DataFrame(data=data_array7, 
                  columns=["time","upCI","lowCI","model"])
#print(df11)

# %%
#FPF-models ###############################################################################################################
df3 = pd.DataFrame(data=data_array3, 
                  columns=["time","upCI","lowCI","model"])
#print(df3)

df4 = pd.DataFrame(data=data_array4, 
                  columns=["time","upCI","lowCI","model"])
#print(df4)

df5 = pd.DataFrame(data=data_array5, 
                  columns=["time","upCI","lowCI","model"])
#print(df5)

# %% [markdown]
# #### Import measured raw data

# %%
IMI_07 = [[0.26, 11.16,  6.68, 19.29],
          [1.00, 32.56, 44.23, 28.37],
          [2.01, 64.18, 64.22, 57.20],
          [3.00, 54.03, 43.32, 59.00],
          [3.99, 46.85, 70.16, 50.28],
          [5.02, 57.44, 50.88, 62.34]]

IMI_18 = [[0.27, 12.96, 15.35, 22.09],
          [0.99, 51.81, 47.85, 63.17],
          [1.95, 88.79, 86.77, 90.76],
          [2.88, 75.66, 72.46, 82.08],
          [3.87, 76.14, 69.32, 71.35],
          [4.99, 62.34, 62.90, 67.42]]

IMIole_18 = [[2.88, 2.62, 1.71, 2.38],
             [3.87, 1.87, 2.14, 2.13],
             [4.99, 2.78, 1.67, 2.98]]

IMI_24 = [[0.24, 16.95, 23.40,  23.83],
          [1.01, 69.93, 74.25,  64.62],
          [1.99, 93.05, 95.68, 112.35],
          [2.94, 68.56, 92.55,  68.71],
          [3.93, 69.47, 65.31,  67.15],
          [5.08, 55.05, 65.18,  57.53]]

IMIole_24 = [[1.99, 2.96, 3.29, 3.59],
             [2.94, 3.04, 6.06, 5.03],
             [3.93, 4.40, 4.28, 4.01],
             [5.08, 3.01, 4.59, 4.21]]


data_IMI_07 = pd.DataFrame(data=IMI_07, 
                  columns=["time","rep1","rep2","rep3"])

data_IMI_18 = pd.DataFrame(data=IMI_18, 
                  columns=["time","rep1","rep2","rep3"])
data_IMIole_18 = pd.DataFrame(data=IMIole_18, 
                  columns=["time","rep1","rep2","rep3"])

data_IMI_24 = pd.DataFrame(data=IMI_24, 
                  columns=["time","rep1","rep2","rep3"])
data_IMIole_24 = pd.DataFrame(data=IMIole_24, 
                  columns=["time","rep1","rep2","rep3"])

# %%
FPF_07 = [[0.27,  7.39,  6.65,  5.18],
          [1.00, 30.59, 17.51, 23.44],
          [2.03, 62.94, 44.62, 31.70],
          [2.99, 32.72, 25.43, 52.62],
          [3.98, 40.31, 39.03, 29.56],
          [5.00, 19.50, 31.79, 42.60]]

FPF_18 = [[0.28,  9.42,  8.97, 12.41],
          [1.00, 25.46, 26.47, 24.27],
          [1.92, 36.49, 46.21, 44.74],
          [2.88, 33.20, 43.04, 35.37],
          [3.88, 37.98, 32.94, 32.62],
          [4.99, 22.94, 36.06, 31.97]]

FPF_24 = [[0.25, 10.00, 10.34, 11.97],
          [1.00, 39.51, 33.98, 25.33],
          [1.97, 36.56, 40.69, 42.12],
          [2.93, 25.72, 33.23, 31.33],
          [3.93, 18.36, 23.68, 23.75],
          [5.08, 14.95, 14.62, 16.54]]

data_FPF_07 = pd.DataFrame(data=FPF_07, 
                  columns=["time","rep1","rep2","rep3"])

data_FPF_18 = pd.DataFrame(data=FPF_18, 
                  columns=["time","rep1","rep2","rep3"])

data_FPF_24 = pd.DataFrame(data=FPF_24, 
                  columns=["time","rep1","rep2","rep3"])

# %% [markdown]
# ## 3. Plot
#
# ### Let's get this data plotted
#
# #### Figure 1:  Internal concentrations and toxicokinetic models of imidacloprid (IMI) and flupyradifurone (FPF) at different temperatures in Gammarus pulex.
# Black dots for IMI (A1-A3) and triangles for FPF (B1-B3) are measured internal concentrations in µg · kg-1 at 7, 18, and 24 °C, respectively. Solid lines are the TK model fits with lower and upper confidence intervals (dotted lines). The grey vertical line represents the transition timepoint from the uptake to the elimination phase for each temperature and chemical.
#
# #### Figure 2: Internal concentration and toxicokinetic model of imidacloprid-olefin (IMI-ole) at different temperatures in Gammarus pulex.
# Empty green and red circles are measured internal concentrations of IMI-ole in µg · kg-1 at 18, and 24 °C, respectively. Solid lines are the TK model fits with lower and upper confidence intervals (dotted lines).

# %%
## Figure 1


fig, ((ax1, ax2, ax3,), 
      ( ax4, ax5, ax6 ))  = plt.subplots(2, 3, ##defining the number of plots (row, columns)
                                        sharex=False, sharey=True,  #'row'
                                        figsize=(20,10))

#Labels 
plt.rc('font', size=15)          # controls default text sizes
ax1.set_ylabel(r'Internal concentration ' 
               '\n'  # Newline
               r'[µg '+u"\u00B7"+' $\mathregular{kg^{-1}}$]') # middle dot symbol: u"\u00B7", kg^-1 = $\mathregular{kg^{-1}}$
ax4.set_ylabel(r'Internal concentration ' 
               '\n'  # Newline
               r'[µg '+u"\u00B7"+' $\mathregular{kg^{-1}}$]') # middle dot symbol: u"\u00B7", kg^-1 = $\mathregular{kg^{-1}}$
ax4.set_xlabel('Time [day]')
ax5.set_xlabel('Time [day]')
ax6.set_xlabel('Time [day]')
###############################################################################################################################

###############################################################################################################################
### IMI Models
#7
#TK-model
ax1.text(0, 130,'A1', fontsize = 15, weight = 'bold')
ax1.set_title('7 '+u'\u00B0'+'C')
ax1.plot(df.time, df.model, color= 'b') 
ax1.plot(df.time, df.upCI, color= 'b', linestyle= ':') 
ax1.plot(df.time, df.lowCI, color= 'b', linestyle= ':')
ax1.fill_between(df.time, df.upCI, df.lowCI, color= 'b', alpha = 0.1)
#Raw data
ax1.errorbar(data_IMI_07.time, data_IMI_07.rep1, color= 'k', fmt='o', ecolor='k', markersize= 8)
ax1.errorbar(data_IMI_07.time, data_IMI_07.rep2, color= 'k', fmt='o', ecolor='k', markersize= 8)
ax1.errorbar(data_IMI_07.time, data_IMI_07.rep3, color= 'k', fmt='o', ecolor='k', markersize= 8)
ax1.vlines(2.01, ymin=0, ymax=130, colors='gray', linestyles='solid') # Vertical line to highlight transition from uptake to elimination phase

#18
#TK-model
ax2.text(0, 130,'A2', fontsize = 15, weight = 'bold')
ax2.set_title('18 '+u'\u00B0'+'C')
ax2.plot(df1.time, df1.model, color= 'g') 
ax2.plot(df1.time, df1.upCI, color= 'g', linestyle= ':') 
ax2.plot(df1.time, df1.lowCI, color= 'g', linestyle= ':')
ax2.fill_between(df1.time, df1.upCI, df1.lowCI, color= 'g', alpha = 0.1)
#Raw data
ax2.errorbar(data_IMI_18.time, data_IMI_18.rep1, color= 'k', fmt='o', ecolor='k', markersize= 8)
ax2.errorbar(data_IMI_18.time, data_IMI_18.rep2, color= 'k', fmt='o', ecolor='k', markersize= 8)
ax2.errorbar(data_IMI_18.time, data_IMI_18.rep3, color= 'k', fmt='o', ecolor='k', markersize= 8)
ax2.vlines(1.95, ymin=0, ymax=130, colors='gray', linestyles='solid') # Vertical line to highlight transition from uptake to elimination phase

#24
#TK-model
ax3.text(0, 130,'A3', fontsize = 15, weight = 'bold')
ax3.set_title('24 '+u'\u00B0'+'C')
ax3.plot(df2.time, df2.model, color= 'r') 
ax3.plot(df2.time, df2.upCI, color= 'r', linestyle= ':') 
ax3.plot(df2.time, df2.lowCI, color= 'r', linestyle= ':')
ax3.fill_between(df2.time, df2.upCI, df2.lowCI, color= 'r', alpha = 0.1)
#Raw data
ax3.errorbar(data_IMI_24.time, data_IMI_24.rep1, color= 'k', fmt='o', ecolor='k', markersize= 8)
ax3.errorbar(data_IMI_24.time, data_IMI_24.rep2, color= 'k', fmt='o', ecolor='k', markersize= 8)
ax3.errorbar(data_IMI_24.time, data_IMI_24.rep3, color= 'k', fmt='o', ecolor='k', markersize= 8)
ax3.vlines(1.99, ymin=0, ymax=130, colors='gray', linestyles='solid') # Vertical line to highlight transition from uptake to elimination phase

###############################################################################################################################

###############################################################################################################################
### FPF Models
#7
#TK-model
ax4.text(0, 130,'B1', fontsize = 15, weight = 'bold')
ax4.plot(df3.time, df3.model, color= 'b') 
ax4.plot(df3.time, df3.upCI, color= 'b', linestyle= ':') 
ax4.plot(df3.time, df3.lowCI, color= 'b', linestyle= ':')
ax4.fill_between(df3.time, df3.upCI, df3.lowCI, color= 'b', alpha = 0.1)
#Raw data
ax4.errorbar(data_FPF_07.time, data_FPF_07.rep1, color= 'k', fmt='^', ecolor='k', markersize= 8)
ax4.errorbar(data_FPF_07.time, data_FPF_07.rep2, color= 'k', fmt='^', ecolor='k', markersize= 8)
ax4.errorbar(data_FPF_07.time, data_FPF_07.rep3, color= 'k', fmt='^', ecolor='k', markersize= 8)
ax4.vlines(2.03, ymin=0, ymax=100, colors='gray', linestyles='solid') # Vertical line to highlight transition from uptake to elimination phase

#18
#TK-Standard
ax5.text(0, 130,'B2', fontsize = 15, weight = 'bold')
ax5.plot(df4.time, df4.model, color= 'g') 
ax5.plot(df4.time, df4.upCI, color= 'g', linestyle= ':') 
ax5.plot(df4.time, df4.lowCI, color= 'g', linestyle= ':')
ax5.fill_between(df4.time, df4.upCI, df4.lowCI, color= 'g', alpha = 0.1)
#Raw data
ax5.errorbar(data_FPF_18.time, data_FPF_18.rep1, color= 'k', fmt='^', ecolor='k', markersize= 8)
ax5.errorbar(data_FPF_18.time, data_FPF_18.rep2, color= 'k', fmt='^', ecolor='k', markersize= 8)
ax5.errorbar(data_FPF_18.time, data_FPF_18.rep3, color= 'k', fmt='^', ecolor='k', markersize= 8)
ax5.vlines(1.92, ymin=0, ymax=100, colors='gray', linestyles='solid') # Vertical line to highlight transition from uptake to elimination phase

#24
#TK-Standard
ax6.text(0, 130,'B3', fontsize = 15, weight = 'bold')
ax6.plot(df5.time, df5.model, color= 'r') 
ax6.plot(df5.time, df5.upCI, color= 'r', linestyle= ':') 
ax6.plot(df5.time, df5.lowCI, color= 'r', linestyle= ':')
ax6.fill_between(df5.time, df5.upCI, df5.lowCI, color= 'r', alpha = 0.1)
#Raw data 
ax6.errorbar(data_FPF_24.time, data_FPF_24.rep1, color= 'k', fmt='^', ecolor='k', markersize= 8)
ax6.errorbar(data_FPF_24.time, data_FPF_24.rep2, color= 'k', fmt='^', ecolor='k', markersize= 8)
ax6.errorbar(data_FPF_24.time, data_FPF_24.rep3, color= 'k', fmt='^', ecolor='k', markersize= 8)
ax6.vlines(1.97, ymin=0, ymax=100, colors='gray', linestyles='solid') # Vertical line to highlight transition from uptake to elimination phase

###############################################################################################################################

###############################################################################################################################
##Uncomment for line labels inside plot
# ax6.plot([df5.time[99]+0.1, df5.time[99]+0.4], #x position
#         [df5.model[99], df5.model[99]],       #y position
#         color='k', alpha=0.5, ls='solid')
# ax6.text(df5.time[99]+0.5, df5.model[99], 'TK model', color='k', va="center")
# ax6.plot([df5.time[99]+0.1, df5.time[99]+0.4], #x position
#         [df5.upCI[99], df5.upCI[99]+3],       #y position
#         color='k', alpha=0.5, ls='solid')
# ax6.text(df5.time[99]+0.5, df5.upCI[99]+3, 'upper CI', color='k', va="center")
# ax6.plot([df5.time[99]+0.1, df5.time[99]+0.4], #x position
#         [df5.lowCI[99], df5.lowCI[99]-3],       #y position
#         color='k', alpha=0.5, ls='solid')
# ax6.text(df5.time[99]+0.5, df5.lowCI[99]-3, 'lower CI', color='k', va="center")
# ax6.plot([df5.time[99]+0.1, df5.time[99]+0.4], #x position
#         [0, 0],                               #y position
#         color='k', alpha=0.5, ls='solid')
# ax6.text(df5.time[99]+0.5, 0, 'water concentration', color='k', va="center")

##Uncomment for savig plots 
#plt.savefig("20220510_TK_parent.pdf")
#plt.savefig("20220510_TK_parent.svg")
# Out:
# Text(5.6816, 0, 'water concentration')

# %%
## Figure 2


#Labels 
plt.rc('font', size=15)          # controls default text sizes
plt.ylabel(r'Internal concentration '
               '\n'  # Newline
               r'[µg '+u"\u00B7"+' $\mathregular{kg^{-1}}$]') # middle dot symbol: u"\u00B7", kg^-1 = $\mathregular{kg^{-1}}$

plt.xlabel('Time [day]')
plt.legend(loc = 'upper left')
###############################################################################################################################

###############################################################################################################################
### IMIole Models
plt.ylim(0, 7)
#18
#TK-model
plt.plot(df6.time, df6.model, color= 'g', label = '18 '+u'\u00B0'+'C') 
plt.plot(df6.time, df6.upCI, color= 'g', linestyle= ':', label = '_nolegend_') 
plt.plot(df6.time, df6.lowCI, color= 'g', linestyle= ':', label = '_nolegend_')
plt.fill_between(df6.time, df6.upCI, df6.lowCI, color= 'g', alpha = 0.1)
#Raw data
plt.errorbar(data_IMIole_18.time, data_IMIole_18.rep1, color= 'g', fmt='o', fillstyle='none', markersize= 8, label = '_nolegend_')
plt.errorbar(data_IMIole_18.time, data_IMIole_18.rep2, color= 'g', fmt='o', fillstyle='none', markersize= 8, label = '_nolegend_')
plt.errorbar(data_IMIole_18.time, data_IMIole_18.rep3, color= 'g', fmt='o', fillstyle='none', markersize= 8, label = '_nolegend_')

#24
#TK-Standard
plt.plot(df7.time, df7.model, color= 'r', label = '24 '+u'\u00B0'+'C') 
plt.plot(df7.time, df7.upCI, color= 'r', linestyle= ':', label = '_nolegend_')
plt.plot(df7.time, df7.lowCI, color= 'r', linestyle= ':', label = '_nolegend_') 
plt.fill_between(df7.time, df7.upCI, df7.lowCI, color= 'r', alpha = 0.1)
#Raw data
plt.errorbar(data_IMIole_24.time, data_IMIole_24.rep1, color= 'r', fmt='o', fillstyle='none', markersize= 8, label = '_nolegend_')
plt.errorbar(data_IMIole_24.time, data_IMIole_24.rep2, color= 'r', fmt='o', fillstyle='none', markersize= 8, label = '_nolegend_')
plt.errorbar(data_IMIole_24.time, data_IMIole_24.rep3, color= 'r', fmt='o', fillstyle='none', markersize= 8, label = '_nolegend_')

###############################################################################################################################

###############################################################################################################################
##Uncomment for line labels inside plot
#Line labels inside plot
#plt.plot([df7.time[99]+0.1, df7.time[99]+0.4], #x position
#         [df7.model[99], df7.model[99]],       #y position
#         color='k', alpha=0.5, ls='solid')
#plt.text(df7.time[99]+0.5, df7.model[99], 'TK model', color='k', va="center")
#plt.plot([df7.time[99]+0.1, df7.time[99]+0.4], #x position
#         [df7.upCI[99], df7.upCI[99]+0.3],       #y position
#         color='k', alpha=0.5, ls='solid')
#plt.text(df7.time[99]+0.5, df7.upCI[99]+0.3, 'upper CI', color='k', va="center")
#plt.plot([df7.time[99]+0.1, df7.time[99]+0.4], #x position
#         [df7.lowCI[99], df7.lowCI[99]-0.3],       #y position
#         color='k', alpha=0.5, ls='solid')
#plt.text(df7.time[99]+0.5, df7.lowCI[99]-0.3, 'lower CI', color='k', va="center")

##Uncomment for savig plots 
#plt.savefig("20220510_TK_metabolite.pdf")
#plt.savefig("20220510_TK_metabolite.svg")

plt.show()

# %% [markdown]
# ## Plot for BCFs
#
# #### Figure S1: Kinetic bioconcentration factors (BCFkin) of imidacloprid (IMI) and flupyradifurone (FPF) in Gammarus  pulex at different temperatures.
# Values can be found in Table S2 and S3.
#
# #### Figure S2: Steady state bioconcentration factor (BCF) after 28 days chronic exposure to 0.3 µg · L-1 at different temperatures.
# BCF = Cint /Cw . Values for internal concentration (Cint) and exposure concentration (Cw) can be found in Mendeley Data (Huang 2022).

# %%
import matplotlib as mpl
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['font.size'] = '15' 
mpl.rcParams['mathtext.default'] = 'regular'  #make sure text with subscript appears regular not italic

# %%
## Figure S2

# Data
FPF = [11.2, 11.0, 4.7]
IMI = [39.7, 24.9, 13.4]
XTemp = [7, 18, 24]

# Plot
fig, ax = plt.subplots(figsize=(5,4))

ax.plot(XTemp, IMI, 'ko', label='IMI', markersize= 8, fillstyle='none')
ax.plot(XTemp, FPF, 'k^', label='FPF', markersize= 8, fillstyle='none')
plt.xticks([7,18,24])
plt.legend()
plt.xlabel('Temperature ['+u'\u00B0'+'C]')
plt.ylabel('$BCF_{kin}$'+' [-]')
plt.rc('font', size=15)          # controls default text sizes
#plt.show()

##Uncomment for savig plots 
# plt.savefig("20220819_BCF-T.pdf", 
#            bbox_inches = 'tight') # so export dosn't cut of label
# plt.savefig("20220819_BCF-T.svg", bbox_inches = 'tight')

# %%
## Figure S2

# Data : BCF=Cint/Cw after 28 days chronic exposure to 3 µg/L 
FPF28 = [17.9, 18.6, 15.1] 
IMI28 = [25.6, 28.5, 27.3]
XTemp28 = [7, 11, 15]

# Plot
fig, ax = plt.subplots(figsize=(5,4))

ax.plot(XTemp28, IMI28, 'ko', label='IMI', markersize= 8, fillstyle='none')
ax.plot(XTemp28, FPF28, 'k^', label='FPF', markersize= 8, fillstyle='none')
plt.xticks([7,11,15])
plt.ylim(0,40)
plt.legend()
plt.xlabel('Temperature ['+u'\u00B0'+'C]')
plt.ylabel('$BCF_{28}$'+' [-]')
plt.rc('font', size=15)          # controls default text sizes
#plt.show()

##Uncomment for savig plots 
# plt.savefig("20220513_BCF-T28.pdf", 
#            bbox_inches = 'tight') # so export dosn't cut of label
# plt.savefig("20220513_BCF-T28.svg", bbox_inches = 'tight')

# %% [markdown]
# # References
